# %%
def f(x,y):
    global e
    e = x + y + e
    return e

c=1
d=2
e=3

# %% [markdown]
# I koden overfor definerer vi ein funksjon f. Vi ser at vi får tilgang til den globale variablen e.

# %%
print (f(c,d)+e)
# Out:
# 12
